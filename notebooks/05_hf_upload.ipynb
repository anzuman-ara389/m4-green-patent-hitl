# %% [markdown]
# # Hugging Face Upload (Model + Dataset)
#
# Upload `data/` (CSV) as dataset repo and `models/finetuned_patentsberta/` as model repo.

# %%
from huggingface_hub import login
login()

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

from src.hf_upload import push_dataset, push_model

HF_USER = "id66pj"
DATASET_REPO = f"{HF_USER}/m4-green-patent-hitl-dataset"
MODEL_REPO   = f"{HF_USER}/m4-green-patent-model"

dataset_link = push_dataset(local_folder="../data", repo_id=DATASET_REPO)
model_link   = push_model(local_folder="../models/finetuned_patentsberta", repo_id=MODEL_REPO)

print("Dataset:", dataset_link)
print("Model:", model_link)
# Out:
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# Dataset: https://huggingface.co/datasets/id66pj/m4-green-patent-hitl-dataset
# Model: https://huggingface.co/id66pj/m4-green-patent-model
